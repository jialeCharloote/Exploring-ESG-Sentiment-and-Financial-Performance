# %% [markdown]
# # Part 2: ESG Sentimental Analysis

# %% [markdown]
# This script is designed for performing ESG (Environmental, Social, Governance) sentiment analysis on a dataset containing company-related content. It leverages a combination of Python libraries and methodologies to preprocess textual data, identify relevant ESG keywords, and compute sentiment scores based on the presence of positive and negative words. The process involves cleaning and tokenizing the text, removing stopwords, stemming, and finally classifying content into ESG categories using a predefined dictionary. Positive and negative sentiment scores are calculated using a list of words from the **Loughran-McDonald Sentiment Word Lists**. Additionally, the script utilizes a pre-trained **Word2Vec model** to enrich the ESG keyword list with similar terms, enhancing the analysis's depth and accuracy. The final output is a DataFrame augmented with ESG scores for each category and a total ESG score for each piece of content, providing insightful metrics to gauge the ESG sentiment within corporate communications.

# %% [markdown]
# ## 2.1: Importing Packages

# %%
### ESG Sentimental Analasis

#prep: import the following packages
from collections import Counter   
import os
import os.path
import string
import nltk
import csv
nltk.download('punkt')
from nltk.tokenize import MWETokenizer  #import tokenizer
from nltk.tokenize import word_tokenize
tokenizer = MWETokenizer()
nltk.download('stopwords')  
from nltk.corpus import stopwords  #import the list of stopwords
from nltk.stem.snowball import SnowballStemmer  #import stemmer module
stemmer = SnowballStemmer('english')
import pandas as pd
import spacy   
nlp = spacy.load('en_core_web_sm') # Load in language package
# Out:
# [nltk_data] Downloading package punkt to /Users/charlotte/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/charlotte/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## 2.2: Function clean_tokenize

# %%
regex_digits = re.compile(r'\d+')
regex_whitespace = re.compile(r'\s+')
english_stopwords = set(stopwords.words('english')) 
stemmer = SnowballStemmer('english')

def clean_tokenize(text):
    """
    Cleans and tokenizes the input text. This includes removing numbers, certain punctuation marks,
    converting to lowercase, and eliminating stopwords. The remaining words are then stemmed.

    Parameters:
    - text (str): The text to be processed.

    Returns:
    - list: A list of stemmed tokens from the input text, excluding stopwords and punctuation.

    """
    # Remove numbers and specific characters
    text_cleaned = regex_digits.sub('', text)
    text_cleaned = text_cleaned.replace('”', '').replace('“', '').replace('—', ' ')

    # Remove punctuations and convert characters to lower case, then trim whitespace
    text_cleaned = "".join([char.lower() for char in text_cleaned if char not in string.punctuation])
    text_cleaned = regex_whitespace.sub(' ', text_cleaned).strip()

    # Tokenize, remove stopwords, and stem
    tokens = word_tokenize(text_cleaned)
    filtered_tokens = [stemmer.stem(word) for word in tokens if word not in english_stopwords]

    return filtered_tokens

# %% [markdown]
# ## 2.3: read_and_process_word_list

# %%
import pandas as pd
import os

def read_and_process_word_list(file_path, sheet_name):
    """
    Reads a word list from a specified sheet in an Excel file, converts words to lowercase,
    and formats them with leading and trailing spaces.

    Parameters:
    - file_path (str): Path to the Excel file.
    - sheet_name (str): Name of the sheet to read.

    Returns:
    - list: A list of processed words.
    """
    df = pd.read_excel(file_path, sheet_name=sheet_name)
    words = df['WORD'].str.lower().tolist()
    return [f' {word} ' for word in words]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read and process the positive, negative excel (LM dictionary)
LM_file_path = '/content/drive/My Drive/Final_Project/Dataset/LM Sentiment Dictionary.xlsx'
positive = read_and_process_word_list(LM_file_path, 'Positive')
negative = read_and_process_word_list(LM_file_path, 'Negative')

# %%
## read company data regarding ESG content
data_file_path = '/content/drive/My Drive/Final_Project/Dataset/Full_data_new.xlsx'
data = pd.read_excel(data_file_path,"Sheet1")
data.head()
# Out:
#    Unnamed: 0 Company name Latin alphabet     Adjust-Company Name Inactive  \
# 0           1                WALMART INC.            WALMART INC.       No
# 1           2            AMAZON.COM, INC.        AMAZON.COM, INC.       No
# 2           4            EXXON MOBIL CORP        EXXON MOBIL CORP       No
# 3           5      CVS HEALTH CORPORATION  CVS HEALTH CORPORATION       No
# 4           7        MCKESSON CORPORATION    MCKESSON CORPORATION       No
#
#   Quoted Branch OwnData Woco Country ISO code  \
# 0    Yes     No      No  Yes               US
# 1    Yes     No      No  Yes               US
# 2    Yes     No      No  Yes               US
# 3    Yes     No      No  Yes               US
# 4    Yes     No      No  Yes               US
#
#    NACE Rev. 2, core code (4 digits)  ... US SIC, primary code(s)  \
# 0                               4719  ...                    5331
# 1                               4791  ...                    5961
# 2                               1920  ...                    2911
# 3                               4773  ...                    5912
# 4                               4645  ...                    5122
#
#    Unnamed: 21  US SIC, primary code(s).1 US SIC, secondary code(s)  \
# 0         5331                       5331                    5411.0
# 1         5961                       5961                    5999.0
# 2         2911                       2911                    1311.0
# 3         5912                       5912                       NaN
# 4         5122                       5122                    5047.0
#
#   National ID National ID type National ID label Ticker symbol      CIK  \
# 0  71-0415188   VAT/Tax number               EIN           WMT   104169
# 1  91-1646860   VAT/Tax number               EIN          AMZN  1018724
# 2  13-5409005   VAT/Tax number               EIN           XOM    34088
# 3  05-0494040   VAT/Tax number               EIN           CVS    64803
# 4  94-3207296   VAT/Tax number               EIN           MCK   927653
#
#                                              Content
# 0  ['Directors, Executive Officers and Corporate ...
# 1  ['Directors, Executive Officers, and Corporate...
# 2  ['Directors, Executive Officers and Corporate ...
# 3  ['Directors, Executive Officers and Corporate ...
# 4  ['Directors, Executive Officers, and Corporate...
#
# [5 rows x 30 columns]

# %%
contents = data["Content"]
contents.head()
# Out:
# 0    ['Directors, Executive Officers and Corporate ...
# 1    ['Directors, Executive Officers, and Corporate...
# 2    ['Directors, Executive Officers and Corporate ...
# 3    ['Directors, Executive Officers and Corporate ...
# 4    ['Directors, Executive Officers, and Corporate...
# Name: Content, dtype: object

# %% [markdown]
# ## 2.4: Building ESG Dictionary
# ——Extracting Similar Words for ESG Keywords Using Word2Vec
#
# This part of the script demonstrates how to load a pre-trained Word2Vec model and utilize it to find words similar to specified ESG (Environmental, Social, Governance) keywords.
#
# The script uses Google's pre-trained Word2Vec model, specifically the 'GoogleNews-vectors-negative300.bin' file, to explore the semantic similarity between the provided ESG keywords and other words in the model's vocabulary.
#
# For each keyword, the script attempts to retrieve the top 10 most similar words based on the model's understanding of semantic similarities.

# %%
from gensim.models import KeyedVectors

# Load a pre-trained Word2Vec model (this example uses Google's pre-trained model)
# Correct path to the .bin file in your Google Drive
model_path = '/content/drive/My Drive/Final_Project/Dataset/GoogleNews-vectors-negative300.bin'

word_vectors = KeyedVectors.load_word2vec_format(model_path, binary=True)

## generate seed words by chatgpt4
esg_keywords = [
    'environment',
    'climate', 'pollution', 'resource', 'biodiversity', 'waste',
    'carbon', 'renewable', 'water', 'deforestation', 'greenhouse',
    'social',
    'rights', 'labor', 'employee', 'diversity', 'community',
    'safety', 'development', 'consumer', 'trade', 'justice',
    'governance',
    'board', 'pay', 'corruption', 'shareholder', 'transparency',
    'ethics', 'risk', 'privacy', 'investment', 'corporate'
]



similar_words = {}
for keyword in esg_keywords:
    # Get the top 10 similar words for each keyword
    try:
        similar_words[keyword] = word_vectors.most_similar(keyword, topn=10)
    except KeyError:
        # This handles cases where the keyword is not in the model's vocabulary
        print(f"{keyword} not found in Word2Vec vocabulary.")

# Display the similar words found
for keyword, words in similar_words.items():
    print(f"\nWords similar to '{keyword}':")
    for word, similarity in words:
        print(f"  {word} (similarity: {similarity})")
# Out:
# Words similar to 'environment':
#   environments (similarity: 0.6948072910308838)
#   enviroment (similarity: 0.6488352417945862)
#   environ_ment (similarity: 0.6331034898757935)
#   enviornment (similarity: 0.6283590793609619)
#   evironment (similarity: 0.6025119423866272)
#   climate (similarity: 0.6009922027587891)
#   envrionment (similarity: 0.5722888708114624)
#   envi_ronment (similarity: 0.5690474510192871)
#   environment.â_€ (similarity: 0.5512977242469788)
#   environement (similarity: 0.5422994494438171)
#
# Words similar to 'climate':
#   climate_change (similarity: 0.6569507122039795)
#   Climate (similarity: 0.6230838298797607)
#   climates (similarity: 0.6195024251937866)
#   global_warming (similarity: 0.6047458648681641)
#   environment (similarity: 0.6009922027587891)
#   climatic (similarity: 0.5555011630058289)
#   climatic_conditions (similarity: 0.5207005143165588)
#   ambassador_Brice_Lalonde (similarity: 0.5172268152236938)
#   Global_warming (similarity: 0.5048916339874268)
#   Climate_Change (similarity: 0.4955976605415344)
#
# Words similar to 'pollution':
#   air_pollution (similarity: 0.8501074910163879)
#   pollutants (similarity: 0.7709959149360657)
#   Pollution (similarity: 0.7395129203796387)
#   pollutant (similarity: 0.6994908452033997)
#   emissions (similarity: 0.6964946985244751)
#   pollutions (similarity: 0.6812856793403625)
#   pollutant_emissions (similarity: 0.677663266658783)
#   polluting (similarity: 0.674841582775116)
#   mercury_pollution (similarity: 0.6734305024147034)
#   polution (similarity: 0.6720529198646545)
#
# Words similar to 'resource':
#   resources (similarity: 0.6914176940917969)
#   Resource (similarity: 0.6077393889427185)
#   resouce (similarity: 0.5431894063949585)
#   operates_ePregnancy.com (similarity: 0.5389664173126221)
#   CAMFT_provides (similarity: 0.5248504877090454)
#   mineral_resources (similarity: 0.5242123007774353)
#   www.nuveen.com_arps (similarity: 0.5222505927085876)
#   JORC_compliant_mineral (similarity: 0.5219569206237793)
#   gross_unrisked_prospective (similarity: 0.5179605484008789)
#   compliant_inferred_mineral (similarity: 0.5125525593757629)
#
# Words similar to 'biodiversity':
#   bio_diversity (similarity: 0.795343279838562)
#   Biodiversity (similarity: 0.7260943055152893)
#   biodiversity_conservation (similarity: 0.7225898504257202)
#   ecosystems (similarity: 0.7113014459609985)
#   marine_biodiversity (similarity: 0.7010886073112488)
#   deforestation (similarity: 0.6493916511535645)
#   ecological (similarity: 0.6492161154747009)
#   ecology (similarity: 0.6430251598358154)
#   habitats (similarity: 0.6427627801895142)
#   fauna (similarity: 0.6406967639923096)
#
# Words similar to 'waste':
#   wastes (similarity: 0.8009456396102905)
#   waste_disposal (similarity: 0.7117306590080261)
#   Waste (similarity: 0.6607858538627625)
#   hazardous_waste (similarity: 0.6397877931594849)
#   garbage (similarity: 0.6332037448883057)
#   recyclable_waste (similarity: 0.603857159614563)
#   landfills (similarity: 0.6020991802215576)
#   recycling (similarity: 0.594290018081665)
#   landfill (similarity: 0.5907027125358582)
#   landfilling (similarity: 0.5821129679679871)
#
# Words similar to 'carbon':
#   carbon_emissions (similarity: 0.7353963255882263)
#   carbon_emission (similarity: 0.7270849347114563)
#   CO2 (similarity: 0.6983804106712341)
#   emissions (similarity: 0.677153468132019)
#   greenhouse_gas (similarity: 0.6718418598175049)
#   emission (similarity: 0.662035346031189)
#   carbon_dioxide_emissions (similarity: 0.6579014658927917)
#   greenhouse_gases (similarity: 0.6523941159248352)
#   greenhouse_gas_emissions (similarity: 0.6497073769569397)
#   carbon_dioxide (similarity: 0.646781861782074)
#
# Words similar to 'renewable':
#   renewable_energy (similarity: 0.8236783146858215)
#   renewables (similarity: 0.7485474944114685)
#   biomass (similarity: 0.6651452779769897)
#   renewable_fuels (similarity: 0.6620936393737793)
#   Renewable (similarity: 0.6499089002609253)
#   biofuels (similarity: 0.6431555151939392)
#   renewable_energies (similarity: 0.6319903135299683)
#   fossil_fuels (similarity: 0.626794695854187)
#   Renewable_energy (similarity: 0.6227798461914062)
#   nonfossil_fuel (similarity: 0.6144607067108154)
#
# Words similar to 'water':
#   potable_water (similarity: 0.6799106001853943)
#   Water (similarity: 0.6706871390342712)
#   sewage (similarity: 0.6619377732276917)
#   groundwater (similarity: 0.6588346362113953)
#   Floridan_aquifer (similarity: 0.6422534584999084)
#   surficial_aquifer (similarity: 0.64188551902771)
#   freshwater (similarity: 0.6307883262634277)
#   potable (similarity: 0.6251927614212036)
#   wastewater (similarity: 0.6212229132652283)
#   brackish_groundwater (similarity: 0.6206730604171753)
#
# Words similar to 'deforestation':
#   tropical_deforestation (similarity: 0.7687509655952454)
#   Deforestation (similarity: 0.7483713626861572)
#   Amazon_deforestation (similarity: 0.7081130146980286)
#   rampant_deforestation (similarity: 0.6855350136756897)
#   rainforest_destruction (similarity: 0.6694349050521851)
#   de_forestation (similarity: 0.6518003940582275)
#   biodiversity (similarity: 0.6493915915489197)
#   tropical_forests (similarity: 0.6454057097434998)
#   desertification (similarity: 0.6277325749397278)
#   rainforests (similarity: 0.6261211633682251)
#
# Words similar to 'greenhouse':
#   greenhouses (similarity: 0.7575361132621765)
#   hydroponic_garden (similarity: 0.5926687717437744)
#   glasshouse (similarity: 0.5922235250473022)
#   unheated_greenhouse (similarity: 0.5891548991203308)
#   Greenhouses (similarity: 0.5876358151435852)
#   Greenhouse (similarity: 0.5655474066734314)
#   hydroponically (similarity: 0.5638698935508728)
#   garden (similarity: 0.5577081441879272)
#   hydroponic_greenhouse (similarity: 0.5530120134353638)
#   glasshouses (similarity: 0.5507873892784119)
#
# Words similar to 'social':
#   Social (similarity: 0.5975170135498047)
#   societal (similarity: 0.5479760766029358)
#   Carmeta_Albarus_Lindo (similarity: 0.5396257042884827)
#   socio (similarity: 0.5287898182868958)
#   media_optimization_SMO (similarity: 0.5130931735038757)
#   cultural (similarity: 0.5111326575279236)
#   fetid_stench_overwhelms (similarity: 0.5087690949440002)
#   social_networking (similarity: 0.5086089968681335)
#   owns_http://www.mywallst.net_financial (similarity: 0.5085837244987488)
#   socio_economic (similarity: 0.502673327922821)
#
# Words similar to 'rights':
#   Rights (similarity: 0.6007217168807983)
#   Kawagib_Moro_human (similarity: 0.5945698618888855)
#   pSivida_owns (similarity: 0.5230460166931152)
#   DMGI_acquires (similarity: 0.5204488039016724)
#   freedoms (similarity: 0.5097455382347107)
#   activist_Heba_Morayef (similarity: 0.5090827941894531)
#   rigths (similarity: 0.5031760334968567)
#   screeners_collective_bargaining (similarity: 0.49878597259521484)
#   inalienable_rights (similarity: 0.49796783924102783)
#   constitutional_protections (similarity: 0.4939669072628021)
#
# Words similar to 'labor':
#   wages (similarity: 0.5397122502326965)
#   Anxiety_Disorder_preterm (similarity: 0.5366857051849365)
#   union (similarity: 0.5315647125244141)
#   HORSHAM_Pa._Child (similarity: 0.529752254486084)
#   labor_unions (similarity: 0.5255804657936096)
#   organizer_Cesar_Chavez (similarity: 0.5241997241973877)
#   reintroduce_nitrous_oxide (similarity: 0.5229582786560059)
#   Peter_Rachleff (similarity: 0.522028386592865)
#   wage (similarity: 0.517335057258606)
#   Virginia_Calvez (similarity: 0.5097293853759766)
#
# Words similar to 'employee':
#   employees (similarity: 0.718955397605896)
#   Employee (similarity: 0.688029408454895)
#   worker (similarity: 0.6614044308662415)
#   employer (similarity: 0.6551854014396667)
#   coworker (similarity: 0.5766790509223938)
#   em_ployee (similarity: 0.5669427514076233)
#   workers (similarity: 0.5474904775619507)
#   Employees (similarity: 0.540514349937439)
#   Gong_Xuefei_Sinohydro (similarity: 0.5400647521018982)
#   staffer (similarity: 0.5374315977096558)
#
# Words similar to 'diversity':
#   cultural_diversity (similarity: 0.7137657999992371)
#   diverse (similarity: 0.6029115915298462)
#   inclusiveness (similarity: 0.5994101166725159)
#   Diversity (similarity: 0.5967464447021484)
#   Amy_Ritchart_covers (similarity: 0.5921353697776794)
#   multicultural (similarity: 0.5805146098136902)
#   culturally_diverse (similarity: 0.559525191783905)
#   geographic_diversity (similarity: 0.5424637198448181)
#   linguistic_diversity (similarity: 0.5390768051147461)
#   inclusivity (similarity: 0.5374331474304199)
#
# Words similar to 'community':
#   communities (similarity: 0.6974058747291565)
#   commmunity (similarity: 0.659652054309845)
#   communty (similarity: 0.6313078999519348)
#   commuity (similarity: 0.6275128722190857)
#   com_munity (similarity: 0.6132515668869019)
#   commu_nity (similarity: 0.6071540117263794)
#   communtiy (similarity: 0.5975485444068909)
#   comunity (similarity: 0.5837293267250061)
#   commnity (similarity: 0.5445207953453064)
#   thecommunity (similarity: 0.5390103459358215)
#
# Words similar to 'safety':
#   saftey (similarity: 0.697494387626648)
#   Safety (similarity: 0.692160964012146)
#   safey (similarity: 0.6256647706031799)
#   SAFETY (similarity: 0.537621021270752)
#   abductees_staggered (similarity: 0.5276590585708618)
#   Broderick_Binns_sack (similarity: 0.5015079975128174)
#   colleague_Angelo_Isenia (similarity: 0.4970751106739044)
#   Jeremy_Pawloski_covers (similarity: 0.4798126220703125)
#   HTH_combines (similarity: 0.4783755838871002)
#   Saftey (similarity: 0.47338101267814636)
#
# Words similar to 'development':
#   develop_ment (similarity: 0.6592977046966553)
#   devel_opment (similarity: 0.6194305419921875)
#   devlopment (similarity: 0.6086612343788147)
#   develpment (similarity: 0.6010811924934387)
#   develoment (similarity: 0.5995140671730042)
#   developement (similarity: 0.5865381360054016)
#   Development (similarity: 0.5766966938972473)
#   de_velopment (similarity: 0.567037045955658)
#   developmentof (similarity: 0.5625792145729065)
#   revitalization (similarity: 0.5615677833557129)
#
# Words similar to 'consumer':
#   consumers (similarity: 0.7439896464347839)
#   Consumer (similarity: 0.737952709197998)
#   Consumers (similarity: 0.5590105056762695)
#   retail (similarity: 0.5538579821586609)
#   CONSUMER (similarity: 0.5371816754341125)
#   consumersâ_€_™ (similarity: 0.5299491286277771)
#   Mona_Bawgus (similarity: 0.5181565880775452)
#   TransUnion_TrueCredit.com (similarity: 0.5067312121391296)
#   distributive_trades (similarity: 0.5064419507980347)
#   consumer_electronics (similarity: 0.5020024180412292)
#
# Words similar to 'trade':
#   trading (similarity: 0.5736494064331055)
#   trades (similarity: 0.5639008283615112)
#   Trade (similarity: 0.5276644229888916)
#   traded (similarity: 0.5155751705169678)
#   TRADE (similarity: 0.4945037364959717)
#   name_Biochronomer (similarity: 0.4810284972190857)
#   agreements_RTAs (similarity: 0.4686906933784485)
#   TransPacific_Partnership (similarity: 0.46493709087371826)
#   EnTourage_Systems_Inc. (similarity: 0.46275925636291504)
#   symbol_ZNWAW (similarity: 0.46124377846717834)
#
# Words similar to 'justice':
#   Bura_Sadoun_Ismael (similarity: 0.6316758394241333)
#   judicial (similarity: 0.5876485109329224)
#   criminal_justice (similarity: 0.5788365602493286)
#   Charge_Fugitive (similarity: 0.5707635879516602)
#   justic (similarity: 0.5563480257987976)
#   Justice (similarity: 0.5556654334068298)
#   equality (similarity: 0.5215687155723572)
#   injustice (similarity: 0.5184529423713684)
#   minister_Herta_Gmelin (similarity: 0.5059308409690857)
#   critic_Vic_Toews (similarity: 0.4977028965950012)
#
# Words similar to 'governance':
#   Governance (similarity: 0.679608941078186)
#   corporate_governance (similarity: 0.6344693303108215)
#   goverance (similarity: 0.6180680990219116)
#   accountability (similarity: 0.5873484015464783)
#   gover_nance (similarity: 0.5654229521751404)
#   compliance_ITGRC_reporting (similarity: 0.5607298016548157)
#   decentralization (similarity: 0.5460370779037476)
#   governances (similarity: 0.5231517553329468)
#   transparency (similarity: 0.5164796113967896)
#   accountabilty (similarity: 0.5066307187080383)
#
# Words similar to 'board':
#   Board (similarity: 0.6730715036392212)
#   directors (similarity: 0.6475344300270081)
#   trustees (similarity: 0.640314519405365)
#   baord (similarity: 0.5922821164131165)
#   Trustees (similarity: 0.5866842269897461)
#   Governing_Board (similarity: 0.5753399729728699)
#   Theresa_Colaizzi (similarity: 0.5700289011001587)
#   Jane_Gallucci (similarity: 0.5602066516876221)
#   boards (similarity: 0.5594164729118347)
#   Pat_Deutschman (similarity: 0.5546655654907227)
#
# Words similar to 'pay':
#   paying (similarity: 0.7515931725502014)
#   paid (similarity: 0.7394721508026123)
#   pays (similarity: 0.6697139739990234)
#   topay (similarity: 0.6145035028457642)
#   reimburse (similarity: 0.6045018434524536)
#   Paying (similarity: 0.5726549029350281)
#   payed (similarity: 0.5668038129806519)
#   payment (similarity: 0.5520696640014648)
#   repay (similarity: 0.549562394618988)
#   Pay (similarity: 0.5482446551322937)
#
# Words similar to 'corruption':
#   rampant_corruption (similarity: 0.7559446096420288)
#   Corruption (similarity: 0.7278581261634827)
#   graft (similarity: 0.7113776206970215)
#   bribery (similarity: 0.7017542123794556)
#   endemic_corruption (similarity: 0.6960716247558594)
#   corrupt (similarity: 0.675744354724884)
#   cronyism (similarity: 0.655494749546051)
#   rampant_graft (similarity: 0.6475235223770142)
#   endemic_graft (similarity: 0.6440584063529968)
#   anticorruption (similarity: 0.6315034031867981)
#
# Words similar to 'shareholder':
#   shareholders (similarity: 0.83296799659729)
#   stockholder (similarity: 0.8287431001663208)
#   Shareholder (similarity: 0.7098876237869263)
#   controlling_shareholder (similarity: 0.6653842329978943)
#   stockholders (similarity: 0.6553466320037842)
#   Shareholders (similarity: 0.6478607654571533)
#   shareowner (similarity: 0.6236246228218079)
#   investor (similarity: 0.6148834824562073)
#   shareholding (similarity: 0.5945608019828796)
#   unitholder (similarity: 0.5786389112472534)
#
# Words similar to 'transparency':
#   Transparency (similarity: 0.7309296727180481)
#   accountability (similarity: 0.6853542327880859)
#   transparancy (similarity: 0.6734080910682678)
#   openness (similarity: 0.6674759387969971)
#   transparent (similarity: 0.6493788957595825)
#   tranparency (similarity: 0.6057917475700378)
#   explosion_romaine_parmesan (similarity: 0.5973690152168274)
#   transparence (similarity: 0.5778376460075378)
#   clarity (similarity: 0.5559980273246765)
#   objectivity (similarity: 0.5470437407493591)
#
# Words similar to 'ethics':
#   Ethics (similarity: 0.6994011402130127)
#   ethical (similarity: 0.6802183985710144)
#   Ethics_Committee (similarity: 0.5982674956321716)
#   ethical_lapses (similarity: 0.5681861639022827)
#   pix_Hacking (similarity: 0.5603845119476318)
#   Ethics_Commission (similarity: 0.5552638173103333)
#   Tibor_Machan_holds (similarity: 0.5488163232803345)
#   Professional_Journalists_Code (similarity: 0.5378056168556213)
#   Judicial_Canons (similarity: 0.5327366590499878)
#   www.ic_software.co.uk (similarity: 0.517051637172699)
#
# Words similar to 'risk':
#   risks (similarity: 0.7139055132865906)
#   Risk (similarity: 0.6394845843315125)
#   probability (similarity: 0.5938692688941956)
#   danger (similarity: 0.5917248725891113)
#   likelihood (similarity: 0.5871133208274841)
#   therisk (similarity: 0.526685357093811)
#   risky (similarity: 0.5120391249656677)
#   Risks (similarity: 0.4975810945034027)
#   hazard (similarity: 0.48922520875930786)
#   peril (similarity: 0.48811477422714233)
#
# Words similar to 'privacy':
#   Privacy (similarity: 0.6946386694908142)
#   IndustryWeek_protects_your (similarity: 0.6353104710578918)
#   confidentiality (similarity: 0.6097476482391357)
#   Joseph_Sanscrainte_telecommunications (similarity: 0.6026305556297302)
#   Gayan_widower (similarity: 0.5934081077575684)
#   commissioner_Jennifer_Stoddart (similarity: 0.5900177359580994)
#   Cris_Carmona (similarity: 0.5651087760925293)
#   Elinor_Mills_covers (similarity: 0.5316537618637085)
#   counsel_Kay_Heidbreder (similarity: 0.5262253284454346)
#   privacies (similarity: 0.5177769660949707)
#
# Words similar to 'investment':
#   investments (similarity: 0.8098693490028381)
#   investing (similarity: 0.7012243270874023)
#   Investment (similarity: 0.6812148094177246)
#   invesment (similarity: 0.6630898118019104)
#   investor (similarity: 0.6319271326065063)
#   invest (similarity: 0.6203395128250122)
#   investors (similarity: 0.5946778655052185)
#   equity (similarity: 0.5897506475448608)
#   investement (similarity: 0.5615226626396179)
#   Investments (similarity: 0.5592135190963745)
#
# Words similar to 'corporate':
#   coporate (similarity: 0.6374416947364807)
#   corporations (similarity: 0.6310545206069946)
#   Corporate (similarity: 0.6277984976768494)
#   please_visit_www.funcom.com (similarity: 0.575084388256073)
#   corportate (similarity: 0.553866982460022)
#   Trademark_footnote (similarity: 0.5390623211860657)
#   www.sodexoUSA.com_blog (similarity: 0.5219446420669556)
#   multinational_corporations (similarity: 0.519289493560791)
#   www.devine_ent.com (similarity: 0.5041453242301941)
#   http://www.ert.com (similarity: 0.5018110871315002)

# %% [markdown]
# ### ESG Dictionary

# %%
esg_dictionary = {
    "Environmental": [
        "climate", "climate change", "climates", "global warming", "climatic", "climatic conditions",
        "pollution", "air pollution", "pollutants", "pollutant", "emissions", "pollutions", "pollutant emissions", "polluting", "mercury pollution",
        "resource", "resources", "mineral resources",
        "biodiversity", "bio diversity", "biodiversity conservation", "ecosystems", "marine biodiversity", "deforestation", "ecological", "ecology", "habitats", "fauna",
        "waste", "wastes", "waste disposal", "hazardous waste", "garbage", "recyclable waste", "landfills", "recycling", "landfill", "landfilling",
        "carbon", "carbon emissions", "carbon emission", "CO2", "greenhouse gas", "emission", "carbon dioxide emissions", "greenhouse gases", "greenhouse gas emissions", "carbon dioxide",
        "renewable", "renewable energy", "renewables", "biomass", "renewable fuels", "biofuels", "renewable energies", "fossil fuels",
        "water", "potable water", "sewage", "groundwater", "freshwater", "potable", "wastewater", "brackish groundwater",
        "deforestation", "tropical deforestation", "Amazon deforestation", "rampant deforestation", "rainforest destruction", "biodiversity", "tropical forests", "desertification", "rainforests",
        "greenhouse", "greenhouses", "hydroponic garden", "glasshouse", "unheated greenhouse", "hydroponically", "garden", "hydroponic greenhouse", "glasshouses"
    ],
    "Social": [
        "rights", "freedoms", "inalienable rights", "constitutional protections",
        "labor", "wages", "union", "labor unions", "wage",
        "employee", "employees", "worker", "employer", "coworker", "workers", "staffer",
        "diversity", "cultural diversity", "diverse", "inclusiveness", "multicultural", "culturally diverse", "geographic diversity", "linguistic diversity", "inclusivity",
        "community", "communities",
        "safety",
        "development", "revitalization",
        "consumer", "consumers", "retail", "consumer electronics",
        "trade", "trading", "trades", "traded",
        "justice", "judicial", "criminal justice", "equality", "injustice"
    ],
    "Governance": [
        "board", "directors", "trustees", "boards",
        "pay", "paying", "paid", "pays", "reimburse", "payment", "repay",
        "corruption", "rampant corruption", "graft", "bribery", "endemic corruption", "corrupt", "cronyism", "rampant graft", "endemic graft", "anticorruption",
        "shareholder", "shareholders", "stockholder", "controlling shareholder", "stockholders", "shareowner", "investor", "shareholding", "unitholder",
        "transparency", "accountability", "openness", "transparent", "clarity", "objectivity",
        "ethics", "ethical", "ethical lapses",
        "risk", "risks", "probability", "danger", "likelihood", "risky", "hazard", "peril",
        "privacy", "confidentiality",
        "investment", "investments", "investing", "investment", "investor", "invest", "investors", "equity", "investement",
        "corporate", "corporations", "multinational corporations"
    ]
}

# %% [markdown]
# ### 2.5: ESG Score Calculation and Appending

# %%
def calculate_esg_scores(text, esg_dictionary, positive_list, negative_list):
    """
    Calculate and normalize sentiment scores for ESG categories based on the presence of relevant keywords,
    the balance of positive and negative words in the text, and the total number of words in the content.
    """
    # Clean and tokenize the text
    tokens = clean_tokenize(text)
    token_counts = Counter(tokens)

    # Calculate the total number of tokens (words) in the content for normalization
    total_tokens = len(tokens)

    scores = {}
    for category, keywords in esg_dictionary.items():
        processed_keywords = [clean_tokenize(kw)[0] for kw in keywords] # Assuming single words
        category_score = sum(token_counts[word] for word in processed_keywords if word in token_counts)
        scores[category] = category_score

    # Calculate positive and negative sentiment scores
    positive_score = sum(token_counts.get(word, 0) for word in positive_list)
    negative_score = sum(token_counts.get(word, 0) for word in negative_list)

    # Adjust scores based on sentiment
    adjusted_scores = {category: score + positive_score - negative_score for category, score in scores.items()}

    # Normalize the adjusted scores by the total number of tokens
    normalized_scores = {category: score / total_tokens if total_tokens > 0 else 0 for category, score in adjusted_scores.items()}

    # Calculate total ESG score and normalize it
    total_esg_score = sum(normalized_scores.values())

    return normalized_scores, total_esg_score

def append_esg_scores_to_df(data, esg_dictionary, positive_list, negative_list):
    """
    Appends normalized ESG scores as new columns to the DataFrame.
    """
    # Initialize columns for scores
    for category in esg_dictionary.keys():
        data[f'{category} Score'] = 0
    data['Total ESG Score'] = 0

    # Calculate, normalize, and append scores for each row
    for index, row in data.iterrows():
        scores, total_esg_score = calculate_esg_scores(row['Content'], esg_dictionary, positive_list, negative_list)
        for category, score in scores.items():
            data.at[index, f'{category} Score'] = score
        data.at[index, 'Total ESG Score'] = total_esg_score

    return data

# %%
# Append ESG scores to the DataFrame
data_with_esg_scores = append_esg_scores_to_df(data, esg_dictionary, positive, negative)

# Display the first few rows to verify the new columns
print(data_with_esg_scores.head())
# Out:
#    Unnamed: 0 Company name Latin alphabet     Adjust-Company Name Inactive  \
# 0           1                WALMART INC.            WALMART INC.       No
# 1           2            AMAZON.COM, INC.        AMAZON.COM, INC.       No
# 2           4            EXXON MOBIL CORP        EXXON MOBIL CORP       No
# 3           5      CVS HEALTH CORPORATION  CVS HEALTH CORPORATION       No
# 4           7        MCKESSON CORPORATION    MCKESSON CORPORATION       No
#
#   Quoted Branch OwnData Woco Country ISO code  \
# 0    Yes     No      No  Yes               US
# 1    Yes     No      No  Yes               US
# 2    Yes     No      No  Yes               US
# 3    Yes     No      No  Yes               US
# 4    Yes     No      No  Yes               US
#
#    NACE Rev. 2, core code (4 digits)  ... National ID  National ID type  \
# 0                               4719  ...  71-0415188    VAT/Tax number
# 1                               4791  ...  91-1646860    VAT/Tax number
# 2                               1920  ...  13-5409005    VAT/Tax number
# 3                               4773  ...  05-0494040    VAT/Tax number
# 4                               4645  ...  94-3207296    VAT/Tax number
#
#    National ID label Ticker symbol      CIK  \
# 0                EIN           WMT   104169
# 1                EIN          AMZN  1018724
# 2                EIN           XOM    34088
# 3                EIN           CVS    64803
# 4                EIN           MCK   927653
#
#                                              Content Environmental Score  \
# 0  ['Directors, Executive Officers and Corporate ...            0.026416
# 1  ['Directors, Executive Officers, and Corporate...            0.030262
# 2  ['Directors, Executive Officers and Corporate ...            0.099589
# 3  ['Directors, Executive Officers and Corporate ...            0.019832
# 4  ['Directors, Executive Officers, and Corporate...            0.024088
#
#   Social Score Governance Score Total ESG Score
# 0     0.045186         0.047619        0.119221
# 1     0.052791         0.050437        0.133490
# 2     0.039699         0.056468        0.195756
# 3     0.074286         0.047395        0.141513
# 4     0.041294         0.044735        0.110117
#
# [5 rows x 34 columns]

# %%
# Export DataFrame to a CSV file
data_with_esg_scores.to_csv('data_with_esg_scores.csv', index=False)
